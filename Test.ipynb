# %%
import pandas as pd

# %%
dicio = pd.read_json('./predictions/few-shot/gpt-4/comic_styles_predictions.json')

# %%
style = 'sarcasm'

for i in dicionario:
    item = dicionario[i]
    ht = item['humorous_text']
    md = item['model_name']
    an_cs = item['annotated_comic_styles']
    md_cs = item['model_comic_styles']
    
    if md == 'gpt-4' and len(ht.split()) <= 80 and an_cs[style] == 1 and md_cs[style] == '1':
        print(ht)
        print('\n')
# Out:
# Humorista: Boa noite! Obrigado, obrigado, obrigado! Muito obrigado! Que legal, muito tempo voltando. É isso aí, hein? Lotadaço! Quantas pessoas tem aqui? Suficiente pra pagar os bagulhos.
# Pessoa: Não, tem 700 pessoas.
# Humorista: 700 pessoas, caralho, foda. Lembrou muito o meu começo. Eu... Eu tava... Não, tava...
# Pessoa: Até porque no Piauí só tem 700 pessoas.
#
#
# Olha como a gente, a nível de humanidade, olha como a gente se acha muito. Imagina Deus, Deus que é Deus. Deus manda o seu único filho morrer por uma humanidade que empurra uma porta que tá escrito PUXE. A gente não tá se achando muito não, tem muito mais em jogo, gente.
#
#
# Humorista: Abandonado pelo pai. Miserável, foi embora, rapaz. Foi... Hã?
# Espectador: Foi comprar cigarro.
# Humorista: Meu pai pode ser ausente, mas ele era crente, viu? Ele não fuma, não. Ele abandona filhos. É diferente.
#
#
# ...
