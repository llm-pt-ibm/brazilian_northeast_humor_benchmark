# %%
# !pip install matplotlib altair pandas altair numpy
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install vl-convert-python
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import altair as alt
import json
import numpy as np
import os
import pandas as pd
import scipy.stats as st

from statistics import mean

# %%
visus_folder_name = 'visualizations'
os.makedirs(visus_folder_name, exist_ok=True)
visus_path = os.path.join(os.getcwd(), visus_folder_name)

# %%
df_zero = pd.read_json('./evaluation/zero-shot/aggregate_metrics.json')
df_zero['setting'] = 'zero-shot'
df_zero
# Out:
#                                              gemma-3-gaia-pt-br-4b-it  \
# punchlines          {'dice_similarity': 0.486908473753753, 'hit_ra...
# comic_styles        {'f1_score': {'fun': 0.867699642431466, 'humor...
# texts_explanations                                           3.391579
#
#                                                 mixtral-8x7b-instruct  \
# punchlines          {'dice_similarity': 0.549397592450793, 'hit_ra...
# comic_styles        {'f1_score': {'fun': 0.8688327316486161, 'humo...
# texts_explanations                                           3.410526
#
#                                                             sabia-3.1  \
# punchlines          {'dice_similarity': 0.6332983368475681, 'hit_r...
# comic_styles        {'f1_score': {'fun': 0.8653846153846151, 'humo...
# texts_explanations                                           4.195789
#
#                                               granite-3-3-8b-instruct  \
# ...

# %%
df_few = pd.read_json('./evaluation/few-shot/aggregate_metrics.json')
df_few['setting'] = 'few-shot'
df_few
# Out:
#                                              gemma-3-gaia-pt-br-4b-it  \
# punchlines          {'dice_similarity': 0.467893562334099, 'hit_ra...
# comic_styles        {'f1_score': {'fun': 0.867699642431466, 'humor...
# texts_explanations                                           3.210526
#
#                                                 mixtral-8x7b-instruct  \
# punchlines          {'dice_similarity': 0.617705271765415, 'hit_ra...
# comic_styles        {'f1_score': {'fun': 0.867699642431466, 'humor...
# texts_explanations                                           3.541053
#
#                                                             sabia-3.1  \
# punchlines          {'dice_similarity': 0.614947308711401, 'hit_ra...
# comic_styles        {'f1_score': {'fun': 0.7482014388489201, 'humo...
# texts_explanations                                           4.090526
#
#                                               granite-3-3-8b-instruct  \
# ...

# %%
df_all = pd.concat([df_zero, df_few])
df_all = df_all.reset_index().rename(columns={'index': 'task'})

df_long = df_all.melt(
    id_vars=['task', 'setting'], 
    var_name='model', 
    value_name='score'
)

df_long.head(3)
# Out:
#                  task    setting                     model  \
# 0          punchlines  zero-shot  gemma-3-gaia-pt-br-4b-it
# 1        comic_styles  zero-shot  gemma-3-gaia-pt-br-4b-it
# 2  texts_explanations  zero-shot  gemma-3-gaia-pt-br-4b-it
#
#                                                score
# 0  {'dice_similarity': 0.486908473753753, 'hit_ra...
# 1  {'f1_score': {'fun': 0.867699642431466, 'humor...
# 2                                           3.391579

# %%
model_short_names = {
    'gemma-3-gaia-pt-br-4b-it': 'Gaia',
    'mixtral-8x7b-instruct': 'Mixtral',
    'sabia-3.1': 'Sabiá',
    'granite-3-3-8b-instruct': 'Granite',
    'gemini-2.5-flash': 'Gemini',
    'gpt-4': 'GPT-4',
    'llama-3-405b-instruct': 'LLaMA',
    'deepseek-r1-0528-qwen3-8b': 'DeepSeek',
    'gervasio-7b-portuguese-ptbr-decoder': 'Gervasio',
    'kimi-k2-0905': 'Kimi-K2'
}

df_long['model'] = df_long['model'].apply(lambda model_name: model_short_names[model_name])
df_long.head(3)
# Out:
#                  task    setting model  \
# 0          punchlines  zero-shot  Gaia
# 1        comic_styles  zero-shot  Gaia
# 2  texts_explanations  zero-shot  Gaia
#
#                                                score
# 0  {'dice_similarity': 0.486908473753753, 'hit_ra...
# 1  {'f1_score': {'fun': 0.867699642431466, 'humor...
# 2                                           3.391579

# %%
def df_to_tabularx(df, caption="My Table", label="tab:mytable"):
    """
    Converte DataFrame em tabela LaTeX no formato tabularx, estilo conferência (com hlines).
    """
    headers = " & ".join([f"\\textbf{{{col}}}" for col in df.columns]) + " \\\\"

    rows = []
    for _, row in df.iterrows():
        row_str = " & ".join([str(val) for val in row]) + " \\\\"
        rows.append(row_str)

    num_cols = df.shape[1]
    col_format = "l" + "c"*(num_cols-1)

    latex_str = (
        "\\begin{table}[ht]\n"
        "\\centering\n"
        f"\\begin{{tabularx}}{{\\columnwidth}}{{{col_format}}}\n"
        "\\hline\n"
        f"{headers}\n"
        "\\hline\n"
        + "\n".join(rows) + "\n"
        "\\hline\n"
        "\\end{tabularx}\n"
        f"\\caption{{{caption}}}\n"
        f"\\label{{{label}}}\n"
        "\\end{table}"
    )

    return latex_str

# %%
base_path = "evaluation"
cenarios = ["zero-shot", "few-shot"]
dados = []

for cenario in cenarios:
    cenario_path = os.path.join(base_path, cenario)
    
    for root, dirs, files in os.walk(cenario_path):
        for file in files:
            if file == "individual_metrics.json":
                file_path = os.path.join(root, file)
                
                with open(file_path, "r", encoding="utf-8") as f:
                    metrics = json.load(f)
                
                for modelo, valores in metrics.items():
                    dados.append({
                        "cenario": cenario,
                        "modelo": modelo,
                        **valores
                    })

df_individuals = pd.DataFrame(dados)
df_individuals['modelo'] = df_individuals['modelo'].apply(lambda model_name: model_short_names[model_name])

df_individuals.head()
# Out:
#      cenario   modelo                                         punchlines  \
# 0  zero-shot     Gaia  [{'video_url': 'https://www.youtube.com/shorts...
# 1  zero-shot  Mixtral  [{'video_url': 'https://www.youtube.com/shorts...
# 2  zero-shot    Sabiá  [{'video_url': 'https://www.youtube.com/shorts...
# 3  zero-shot  Granite  [{'video_url': 'https://www.youtube.com/shorts...
# 4  zero-shot   Gemini  [{'video_url': 'https://www.youtube.com/shorts...
#
#                                         comic_styles  \
# 0  [{'video_url': 'https://www.youtube.com/shorts...
# 1  [{'video_url': 'https://www.youtube.com/shorts...
# 2  [{'video_url': 'https://www.youtube.com/shorts...
# 3  [{'video_url': 'https://www.youtube.com/shorts...
# 4  [{'video_url': 'https://www.youtube.com/shorts...
#
#                                   texts_explanations
# 0  [{'video_url': 'https://www.youtube.com/shorts...
# 1  [{'video_url': 'https://www.youtube.com/shorts...
# ...

# %% [markdown]
# ### 1. Punchlines

# %%
# 1. Filtrar só punchlines
df_punch = df_long.query("task == 'punchlines'").copy()
df_punch
# Out:
#           task    setting     model  \
# 0   punchlines  zero-shot      Gaia
# 3   punchlines   few-shot      Gaia
# 6   punchlines  zero-shot   Mixtral
# 9   punchlines   few-shot   Mixtral
# 12  punchlines  zero-shot     Sabiá
# 15  punchlines   few-shot     Sabiá
# 18  punchlines  zero-shot   Granite
# 21  punchlines   few-shot   Granite
# 24  punchlines  zero-shot    Gemini
# 27  punchlines   few-shot    Gemini
# 30  punchlines  zero-shot     GPT-4
# 33  punchlines   few-shot     GPT-4
# 36  punchlines  zero-shot  Gervasio
# 39  punchlines   few-shot  Gervasio
# 42  punchlines  zero-shot     LLaMA
# 45  punchlines   few-shot     LLaMA
# 48  punchlines  zero-shot   Kimi-K2
# 51  punchlines   few-shot   Kimi-K2
# 54  punchlines  zero-shot  DeepSeek
# 57  punchlines   few-shot  DeepSeek
#
#                                                 score
# 0   {'dice_similarity': 0.486908473753753, 'hit_ra...
# 3   {'dice_similarity': 0.467893562334099, 'hit_ra...
# ...

# %%
valid_models = [
    model for model in df_punch['model'].unique()
    if all(
        isinstance(v, dict) and v.get('dice_similarity') is not None
        for v in df_punch.loc[df_punch['model'] == model, 'score']
    )
]

df_punch_plot = df_punch[df_punch['model'].isin(valid_models)]

# %%
def to_list(x):
    if isinstance(x, str):
        return json.loads(x)
    elif isinstance(x, list):
        return x
    else:
        return []

df_individuals['punchlines'] = df_individuals['punchlines'].apply(to_list)
df_exploded = df_individuals.explode('punchlines')
df_exploded = df_exploded.rename(columns={'punchlines': 'punchlines'})
df_exploded = df_exploded[['cenario', 'modelo', 'punchlines']]

df_exploded['dice_sim'] = df_exploded['punchlines'].apply(lambda x: x['dice_similarity'])
df_exploded.head()
# Out:
#      cenario modelo                                         punchlines  \
# 0  zero-shot   Gaia  {'video_url': 'https://www.youtube.com/shorts/...
# 0  zero-shot   Gaia  {'video_url': 'https://www.youtube.com/shorts/...
# 0  zero-shot   Gaia  {'video_url': 'https://www.youtube.com/shorts/...
# 0  zero-shot   Gaia  {'video_url': 'https://www.youtube.com/shorts/...
# 0  zero-shot   Gaia  {'video_url': 'https://www.youtube.com/shorts/...
#
#    dice_sim
# 0  0.243902
# 0  0.297872
# 0  0.626866
# 0  0.193548
# 0  0.636364

# %%
# Contar valores nulos ANTES de dropna
null_counts = (
    df_exploded[df_exploded['dice_sim'].isna()]
    .groupby(['cenario', 'modelo'])
    .size()
    .reset_index(name='null_count')
)

# Total de registros por cenário e modelo ANTES de dropna
total_counts = (
    df_exploded.groupby(['cenario', 'modelo'])
    .size()
    .reset_index(name='total_count')
)

# Mesclar as informações
null_summary = null_counts.merge(total_counts, on=['cenario', 'modelo'], how='outer').fillna(0)
null_summary['null_count'] = null_summary['null_count'].astype(int)
null_summary['percentage'] = (null_summary['null_count'] / null_summary['total_count'] * 100).round(2)

print("Valores nulos por cenário e modelo (ANTES de dropna):")
print(null_summary.to_string(index=False))
# Out:
# Valores nulos por cenário e modelo (ANTES de dropna):
#   cenario   modelo  null_count  total_count  percentage
#  few-shot DeepSeek         377          475       79.37
#  few-shot    GPT-4           1          475        0.21
#  few-shot     Gaia         136          475       28.63
#  few-shot   Gemini           2          475        0.42
#  few-shot Gervasio         475          475      100.00
#  few-shot  Granite         451          475       94.95
#  few-shot  Kimi-K2           3          475        0.63
#  few-shot    LLaMA           5          475        1.05
#  few-shot  Mixtral          12          475        2.53
#  few-shot    Sabiá          22          475        4.63
# zero-shot DeepSeek         400          475       84.21
# zero-shot    GPT-4           1          475        0.21
# zero-shot     Gaia           3          475        0.63
# zero-shot   Gemini           3          475        0.63
# zero-shot Gervasio         465          475       97.89
# ...

# %%
df_exploded['dice_sim'] = pd.to_numeric(df_exploded['dice_sim'], errors='coerce')
df_exploded = df_exploded.dropna(subset=['dice_sim'])

# t de Student implementation
""" def mean_confidence_interval(data, confidence=0.95):
    n = len(data)
    mean = data.mean()
    if n < 2:
        return mean, mean, mean
    se = st.sem(data)
    h = se * st.t.ppf((1 + confidence) / 2., n-1)
    return mean, mean - h, mean + h """

# Bootstrap implementation
def mean_confidence_interval(data, confidence=0.95, B=10000, seed=37):
    data = np.asarray(data)
    n = len(data)
    mean = data.mean()

    if n < 2:
        return mean, mean, mean

    rng = np.random.default_rng(seed)

    # Bootstrap das médias
    boot_means = np.array([
        data[rng.integers(0, n, n)].mean()
        for _ in range(B)
    ])

    lower = np.percentile(boot_means, (1 - confidence) / 2 * 100)
    upper = np.percentile(boot_means, (1 + confidence) / 2 * 100)

    return mean, lower, upper

summary_list = []
for (cenario, modelo), group in df_exploded.groupby(['cenario', 'modelo']):
    mean, ci_lower, ci_upper = mean_confidence_interval(group['dice_sim'])
    summary_list.append({
        'cenario': cenario,
        'modelo': modelo,
        'mean': mean,
        'ci_lower': ci_lower,
        'ci_upper': ci_upper
    })

summary_df = pd.DataFrame(summary_list)
summary_df.head()
# Out:
#     cenario    modelo      mean  ci_lower  ci_upper
# 0  few-shot  DeepSeek  0.465176  0.411722  0.520166
# 1  few-shot     GPT-4  0.728419  0.711119  0.746039
# 2  few-shot      Gaia  0.467894  0.441018  0.494560
# 3  few-shot    Gemini  0.717462  0.697472  0.737164
# 4  few-shot   Granite  0.543743  0.427558  0.662376

# %%
import matplotlib.pyplot as plt

# Incluir modelos com valores nulos no gráfico
summary_df_plot = summary_df.copy()

# Encontrar combinações cenario-modelo que existem em null_summary mas não em summary_df
all_combinations = null_summary[['cenario', 'modelo']].drop_duplicates()
existing_combinations = summary_df[['cenario', 'modelo']].drop_duplicates()

missing_combinations = all_combinations.merge(
    existing_combinations, 
    on=['cenario', 'modelo'], 
    how='left', 
    indicator=True
).query("_merge == 'left_only'")[['cenario', 'modelo']]

# Adicionar linhas com mean=0, ci_lower=0, ci_upper=0 para modelos com todos nulos
if len(missing_combinations) > 0:
    null_rows = missing_combinations.copy()
    null_rows['mean'] = 0.0
    null_rows['ci_lower'] = 0.0
    null_rows['ci_upper'] = 0.0
    summary_df_plot = pd.concat([summary_df, null_rows], ignore_index=True)

# Calcula erros
summary_df_plot["error_lower"] = summary_df_plot["mean"] - summary_df_plot["ci_lower"]
summary_df_plot["error_upper"] = summary_df_plot["ci_upper"] - summary_df_plot["mean"]

# Lista de cenários únicos
cenarios = summary_df_plot["cenario"].unique()

for c in cenarios:
    df_c = summary_df_plot[summary_df_plot["cenario"] == c].copy()
    df_c = df_c.sort_values("mean") 

    plt.figure(figsize=(7, 4))

    plt.errorbar(
        x=df_c["mean"],
        y=df_c["modelo"],
        xerr=[df_c["error_lower"], df_c["error_upper"]],
        fmt='o',
        color="black",
        ecolor="black",
        capsize=3
    )

    plt.axvline(0, color='black', linestyle='--', alpha=0.4)
    plt.title(f"", fontsize=12, color="black")
    plt.xlabel("Similaridade de Dice (IC 95%)", color="black")
    plt.ylabel("", color="black")
    plt.grid(False)

    plt.gca().spines['bottom'].set_color('black')
    plt.gca().spines['left'].set_color('black')
    plt.gca().tick_params(axis='x', colors='black')
    plt.gca().tick_params(axis='y', colors='black')

    plt.tight_layout()
    plt.savefig(os.path.join(visus_path, f"similaridade_dice_{c}_intervalo_confianca.png"), dpi=300)
    plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# --- PREPARAÇÃO DOS DADOS ---
# (Mantendo a lógica original de tratamento de nulos e cálculo de erro)

summary_df_plot = summary_df.copy()

all_combinations = null_summary[['cenario', 'modelo']].drop_duplicates()
existing_combinations = summary_df[['cenario', 'modelo']].drop_duplicates()

missing_combinations = all_combinations.merge(
    existing_combinations, 
    on=['cenario', 'modelo'], 
    how='left', 
    indicator=True
).query("_merge == 'left_only'")[['cenario', 'modelo']]

if len(missing_combinations) > 0:
    null_rows = missing_combinations.copy()
    null_rows['mean'] = 0.0
    null_rows['ci_lower'] = 0.0
    null_rows['ci_upper'] = 0.0
    summary_df_plot = pd.concat([summary_df, null_rows], ignore_index=True)

summary_df_plot["error_lower"] = summary_df_plot["mean"] - summary_df_plot["ci_lower"]
summary_df_plot["error_upper"] = summary_df_plot["ci_upper"] - summary_df_plot["mean"]

# --- PLOTAGEM ---

# Ordenação (pela média geral)
model_order = summary_df_plot.groupby("modelo")["mean"].mean().sort_values().index.tolist()

cenarios = summary_df_plot["cenario"].unique()
colors = ["#1f77b4", "#d62728"] # Azul e Vermelho
markers = ['o', 's']
height = 0.3 # Deslocamento vertical para não sobrepor

# Aumentei a largura da figura para acomodar a fonte maior dos nomes
plt.figure(figsize=(10, 8)) 

y_base = np.arange(len(model_order))

# Grid horizontal para guiar o olhar (linha fina cinza)
plt.grid(axis='y', linestyle='--', color='gray', alpha=0.5, zorder=0)
plt.grid(axis='x', linestyle=':', color='gray', alpha=0.3, zorder=0)

for i, cenario in enumerate(cenarios):
    df_c = summary_df_plot[summary_df_plot["cenario"] == cenario].set_index("modelo")
    df_c = df_c.reindex(model_order)
    
    offset = (i - 0.5) * height 
    y_pos = y_base + offset
    
    color = colors[i % len(colors)]
    marker = markers[i % len(markers)]

    plt.errorbar(
        x=df_c["mean"],
        y=y_pos,
        xerr=[df_c["error_lower"], df_c["error_upper"]],
        fmt=marker,
        color=color,
        ecolor=color,
        capsize=5, # Capsize um pouco maior
        label=cenario,
        alpha=0.9,
        markersize=8, # Marcador maior
        zorder=3 
    )

# --- ESTILIZAÇÃO E FONTES ---

# Eixo Y (Nomes dos Modelos) - FONTE AUMENTADA
plt.yticks(y_base, model_order, fontsize=15, color="black")

# Eixo X (Valores numéricos)
plt.xticks(fontsize=15, color="black")

# Legenda do Eixo X - FONTE AUMENTADA
plt.xlabel("Média das Similaridades de Dice (IC 95%)", fontsize=16, color="black", labelpad=12)

# Linha vertical no zero
plt.axvline(0, color='black', linestyle='-', alpha=0.3, linewidth=1.5, zorder=1)

# --- BORDAS (SPINES) ---
# Restaurando a caixa preta completa (Top, Bottom, Left, Right)
ax = plt.gca()
ax.spines['bottom'].set_color('black')
ax.spines['bottom'].set_linewidth(1.0)

ax.spines['left'].set_color('black')
ax.spines['left'].set_linewidth(1.0)

ax.spines['top'].set_visible(True)    # Garante que apareça
ax.spines['top'].set_color('black')   # Cor preta
ax.spines['top'].set_linewidth(1.0)

ax.spines['right'].set_visible(True)  # Garante que apareça
ax.spines['right'].set_color('black') # Cor preta
ax.spines['right'].set_linewidth(1.0)

# Legenda
plt.legend(title="Cenário", title_fontsize=10, fontsize=10, loc='lower right', framealpha=1, edgecolor='black')

plt.tight_layout()
plt.savefig(os.path.join(visus_path, "similaridade_dice_comparativo_unificado.png"), dpi=300)
plt.show()

# %%
summary_df_latex = summary_df.to_latex(index=False, float_format="%.3f".__mod__)
print(summary_df_latex)
# Out:
# \begin{tabular}{llrrr}
# \toprule
# cenario & modelo & mean & ci_lower & ci_upper \\
# \midrule
# few-shot & DeepSeek & 0.465 & 0.412 & 0.520 \\
# few-shot & GPT-4 & 0.728 & 0.711 & 0.746 \\
# few-shot & Gaia & 0.468 & 0.441 & 0.495 \\
# few-shot & Gemini & 0.717 & 0.697 & 0.737 \\
# few-shot & Granite & 0.544 & 0.428 & 0.662 \\
# few-shot & Kimi-K2 & 0.666 & 0.644 & 0.688 \\
# few-shot & LLaMA & 0.654 & 0.631 & 0.676 \\
# few-shot & Mixtral & 0.618 & 0.599 & 0.636 \\
# few-shot & Sabiá & 0.615 & 0.594 & 0.636 \\
# zero-shot & DeepSeek & 0.194 & 0.139 & 0.254 \\
# zero-shot & GPT-4 & 0.730 & 0.714 & 0.747 \\
# zero-shot & Gaia & 0.487 & 0.464 & 0.510 \\
# zero-shot & Gemini & 0.682 & 0.661 & 0.703 \\
# zero-shot & Gervasio & 0.012 & 0.000 & 0.029 \\
# zero-shot & Granite & 0.559 & 0.538 & 0.580 \\
# zero-shot & Kimi-K2 & 0.661 & 0.640 & 0.682 \\
# zero-shot & LLaMA & 0.595 & 0.571 & 0.618 \\
# zero-shot & Mixtral & 0.549 & 0.528 & 0.570 \\
# ...

# %% [markdown]
# ### 2. Humor Reasoning

# %%
df_texts = df_long.query("task == 'texts_explanations'").copy()
df_texts_plot = df_texts[df_texts['model'].isin(valid_models)]
df_texts_plot
# Out:
#                   task    setting     model     score
# 2   texts_explanations  zero-shot      Gaia  3.391579
# 5   texts_explanations   few-shot      Gaia  3.210526
# 8   texts_explanations  zero-shot   Mixtral  3.410526
# 11  texts_explanations   few-shot   Mixtral  3.541053
# 14  texts_explanations  zero-shot     Sabiá  4.195789
# 17  texts_explanations   few-shot     Sabiá  4.090526
# 20  texts_explanations  zero-shot   Granite  3.642105
# 23  texts_explanations   few-shot   Granite  3.543158
# 26  texts_explanations  zero-shot    Gemini  4.635789
# 29  texts_explanations   few-shot    Gemini  4.307368
# 32  texts_explanations  zero-shot     GPT-4  4.282105
# 35  texts_explanations   few-shot     GPT-4  4.164211
# 44  texts_explanations  zero-shot     LLaMA  3.972632
# 47  texts_explanations   few-shot     LLaMA  3.696842
# 50  texts_explanations  zero-shot   Kimi-K2  4.256842
# 53  texts_explanations   few-shot   Kimi-K2  4.067368
# ...

# %%
files = {
    "zero-shot": "evaluation/zero-shot/texts_explanations_evaluation_results.json",
    "few-shot": "evaluation/few-shot/texts_explanations_evaluation_results.json"
}

records = []

for setting, filepath in files.items():
    with open(filepath, "r", encoding="utf-8") as f:
        data = json.load(f)

    for model, videos in data.items():
        for video_url, content in videos.items():
            nivel = int(content["judge_model_results"]["nivel_concordancia"])
            model_text_explanation = content['model_text_explanation']
            annotated_text_explanation = content['annotated_text_explanation']

            records.append({
                "model": model,
                "video_url": video_url,
                'model_text_explanation': model_text_explanation,
                'annotated_text_explanation': annotated_text_explanation,
                "nivel_concordancia": nivel,
                "setting": setting
            })

df = pd.DataFrame(records)
df.head(3)
# Out:
#               model                                          video_url  \
# 0  gemini-2.5-flash  https://www.youtube.com/shorts/Xcve3ifSxWg?fea...
# 1  gemini-2.5-flash  https://www.youtube.com/shorts/QV80EKixLYc?fea...
# 2  gemini-2.5-flash  https://www.youtube.com/shorts/yn3-Kmp7hjM?fea...
#
#                               model_text_explanation  \
# 0  O humor reside na **absurdidade e na quebra de...
# 1  O humor reside principalmente na **quebra de e...
# 2  O humor reside na **hipérbole** e na **absurdi...
#
#                           annotated_text_explanation  nivel_concordancia  \
# 0  O humorista narra uma cena tensa, porém cômica...                   4
# 1  O humorista desdenha da marca Crystal a partir...                   5
# 2  O humorista brinca de maneira criativa sobre o...                   5
#
#      setting
# 0  zero-shot
# 1  zero-shot
# 2  zero-shot

# %%
df_sample = (
    df.groupby('nivel_concordancia', group_keys=False)
      .apply(lambda x: x.sample(frac=0.05, random_state=37))
)

os.makedirs('samples', exist_ok=True)
df_sample.to_csv('samples/sample_explanations.csv', index=False)
# Out:
# /tmp/ipykernel_8135/2244244149.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(frac=0.05, random_state=37))

# %%
# Validated model judging

df_sample_vld_judge = pd.read_csv('samples/sample_explanations_validated.csv')
(
    df_sample_vld_judge
    .groupby('nivel_concordancia')['is_valid']
    .mean()
    .mul(100)
    .round(2)
)
# Out:
# nivel_concordancia
# 1    72.73
# 2    70.97
# 3    80.00
# 4    79.41
# 5    75.00
# Name: is_valid, dtype: float64

# %%
df_counts = (
    df.groupby(["model", "setting", "nivel_concordancia"])
    .size()
    .reset_index(name="count")
)

df_counts["proportion"] = (
    df_counts["count"] / 
    df_counts.groupby(["model", "setting"])["count"].transform("sum")
)

df_counts['model'] = df_counts['model'].apply(lambda model_name: model_short_names[model_name])

df_counts.head()
# Out:
#       model   setting  nivel_concordancia  count  proportion
# 0  DeepSeek  few-shot                   1    190    0.400000
# 1  DeepSeek  few-shot                   2    169    0.355789
# 2  DeepSeek  few-shot                   3     24    0.050526
# 3  DeepSeek  few-shot                   4     54    0.113684
# 4  DeepSeek  few-shot                   5     38    0.080000

# %%
df_counts[df_counts['model'] == 'Sabiá']
# Out:
#     model    setting  nivel_concordancia  count  proportion
# 90  Sabiá   few-shot                   1     11    0.023158
# 91  Sabiá   few-shot                   2     81    0.170526
# 92  Sabiá   few-shot                   3     25    0.052632
# 93  Sabiá   few-shot                   4     95    0.200000
# 94  Sabiá   few-shot                   5    263    0.553684
# 95  Sabiá  zero-shot                   1     16    0.033684
# 96  Sabiá  zero-shot                   2     65    0.136842
# 97  Sabiá  zero-shot                   3     14    0.029474
# 98  Sabiá  zero-shot                   4     95    0.200000
# 99  Sabiá  zero-shot                   5    285    0.600000

# %%
df_45 = df_counts[df_counts["nivel_concordancia"].isin([4, 5])]
soma_45 = (
    df_45.groupby(["model", "setting"])["proportion"]
    .sum()
    .reset_index()
)

pivot = soma_45.pivot(index="model", columns="setting", values="proportion").reset_index()
pivot["sum"] = (pivot["zero-shot"]).round(2)

pivot = pivot.sort_values(by='sum', ascending=False)

print(pivot)
# Out:
# setting     model  few-shot  zero-shot   sum
# 3          Gemini  0.837895   0.911579  0.91
# 1           GPT-4  0.797895   0.808421  0.81
# 6         Kimi-K2  0.743158   0.806316  0.81
# 9           Sabiá  0.753684   0.800000  0.80
# 7           LLaMA  0.648421   0.732632  0.73
# 5         Granite  0.597895   0.621053  0.62
# 2            Gaia  0.475789   0.551579  0.55
# 8         Mixtral  0.587368   0.532632  0.53
# 0        DeepSeek  0.193684   0.370526  0.37
# 4        Gervasio  0.077895   0.061053  0.06

# %%
model_order = pivot['model'].tolist()

heatmap_layer = alt.layer(
    alt.Chart(df_counts).mark_rect().encode(
        x=alt.X("nivel_concordancia:N", 
            title="Nível de Concordância", 
            axis=alt.Axis(labelAngle=0)
        ),
        y=alt.Y("model:N", title=None, sort=model_order),
        color=alt.Color(
            "proportion:Q",
            title="Proportion",
            scale=alt.Scale(scheme="blues", domain=[0, 1]),
            legend=alt.Legend(
                orient="right",
                gradientLength=200,
                title=None,
                gradientThickness=8,
                offset=6
            )
        ),
        tooltip=["model", "setting", "nivel_concordancia", "proportion"]
    ).properties(
        width={'step': 40},
        height=400
    ),
    alt.Chart(df_counts).mark_text(fontSize=12.5).encode(
        x=alt.X("nivel_concordancia:N"),
        y=alt.Y("model:N", sort=model_order),
        text=alt.Text("proportion:Q", format=".2f"),
        color=alt.condition(
            'datum.proportion > 0.5',
            alt.value('white'),
            alt.value('black')
        )
    )
)

heatmap_with_text = heatmap_layer.facet(
    column=alt.Column(
        "setting:N",
        title="",
        sort=["zero-shot", "few-shot"],
        header=alt.Header(
            titleOrient="top",
            labelOrient="top",
            labelAlign="center",
            labelFontSize=14
        )
    )
).properties(
    title={"text": ""}
)

heatmap_with_text.save(os.path.join(visus_path, "expl_1.png"), scale_factor=5.0)
heatmap_with_text.show()
# Out:
# alt.FacetChart(...)

# %% [markdown]
# ### 3. Comic Styles

# %%
df_comic = df_long.query("task == 'comic_styles'").copy()
df_comic.head(3)
# Out:
#            task    setting    model  \
# 1  comic_styles  zero-shot     Gaia
# 4  comic_styles   few-shot     Gaia
# 7  comic_styles  zero-shot  Mixtral
#
#                                                score
# 1  {'f1_score': {'fun': 0.867699642431466, 'humor...
# 4  {'f1_score': {'fun': 0.867699642431466, 'humor...
# 7  {'f1_score': {'fun': 0.8688327316486161, 'humo...

# %%
df_comic_plot = df_comic[
    df_comic['score'].apply(lambda x: isinstance(x, dict) and 'f1_macro' in x)
].copy()

df_comic_plot['score'] = df_comic_plot['score'].apply(lambda x: x['f1_macro'])

# %%
print(df_comic_plot.to_latex(index=False, float_format="%.3f".__mod__))
# Out:
# \begin{tabular}{lllr}
# \toprule
# task & setting & model & score \\
# \midrule
# comic_styles & zero-shot & Gaia & 0.125 \\
# comic_styles & few-shot & Gaia & 0.125 \\
# comic_styles & zero-shot & Mixtral & 0.140 \\
# comic_styles & few-shot & Mixtral & 0.195 \\
# comic_styles & zero-shot & Sabiá & 0.200 \\
# comic_styles & few-shot & Sabiá & 0.248 \\
# comic_styles & zero-shot & Granite & 0.184 \\
# comic_styles & few-shot & Granite & 0.214 \\
# comic_styles & zero-shot & Gemini & 0.249 \\
# comic_styles & few-shot & Gemini & 0.248 \\
# comic_styles & zero-shot & GPT-4 & 0.248 \\
# comic_styles & few-shot & GPT-4 & 0.240 \\
# comic_styles & zero-shot & Gervasio & 0.133 \\
# comic_styles & few-shot & Gervasio & 0.125 \\
# comic_styles & zero-shot & LLaMA & 0.243 \\
# comic_styles & few-shot & LLaMA & 0.224 \\
# comic_styles & zero-shot & Kimi-K2 & 0.249 \\
# comic_styles & few-shot & Kimi-K2 & 0.248 \\
# comic_styles & zero-shot & DeepSeek & 0.125 \\
# ...
