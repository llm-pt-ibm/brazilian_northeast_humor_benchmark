# %%
# !pip install matplotlib vl-convert-python altair pandas operator altair
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement operator (from versions: none)
# ERROR: No matching distribution found for operator

# %%
import altair as alt
import json
import pandas as pd
import operator
import os
import re
import matplotlib.pyplot as plt

from statistics import mean

# %%
visus_folder_name = 'visualizations'
os.makedirs(visus_folder_name, exist_ok=True)
visus_path = os.path.join(os.getcwd(), visus_folder_name)

# %%
df_zero = pd.read_json('./evaluation/zero-shot/aggregate_metrics.json')
df_zero['setting'] = 'zero-shot'
df_zero
# Out:
#                                              gemma-3-gaia-pt-br-4b-it  \
# punchlines          {'dice_similarity': 0.486908473753753, 'hit_ra...
# comic_styles        {'f1_score': {'fun': 0.867699642431466, 'humor...
# texts_explanations                                           3.391579
#
#                                             mixtral-8x7b-instruct-v01  \
# punchlines          {'dice_similarity': 0.549397592450793, 'hit_ra...
# comic_styles        {'f1_score': {'fun': 0.8688327316486161, 'humo...
# texts_explanations                                           3.364211
#
#                                                             sabia-3.1  \
# punchlines          {'dice_similarity': 0.6332983368475681, 'hit_r...
# comic_styles        {'f1_score': {'fun': 0.8653846153846151, 'humo...
# texts_explanations                                           4.195789
#
#                                               granite-3-3-8b-instruct  \
# ...

# %%
df_few = pd.read_json('./evaluation/few-shot/aggregate_metrics.json')
df_few['setting'] = 'few-shot'
df_few
# Out:
#                                              gemma-3-gaia-pt-br-4b-it  \
# punchlines          {'dice_similarity': 0.467893562334099, 'hit_ra...
# comic_styles        {'f1_score': {'fun': 0.867699642431466, 'humor...
# texts_explanations                                           3.210526
#
#                                                             sabia-3.1  \
# punchlines          {'dice_similarity': 0.614947308711401, 'hit_ra...
# comic_styles        {'f1_score': {'fun': 0.7482014388489201, 'humo...
# texts_explanations                                           4.090526
#
#                                               granite-3-3-8b-instruct  \
# punchlines          {'dice_similarity': 0.5437433490380701, 'hit_r...
# comic_styles        {'f1_score': {'fun': 0.8158567774936061, 'humo...
# texts_explanations                                           3.543158
#
#                                                      gemini-2.5-flash  \
# ...

# %%
df_all = pd.concat([df_zero, df_few])
df_all = df_all.reset_index().rename(columns={'index': 'task'})

df_long = df_all.melt(
    id_vars=['task', 'setting'], 
    var_name='model', 
    value_name='score'
)

df_long
# Out:
#                   task    setting                                model  \
# 0           punchlines  zero-shot             gemma-3-gaia-pt-br-4b-it
# 1         comic_styles  zero-shot             gemma-3-gaia-pt-br-4b-it
# 2   texts_explanations  zero-shot             gemma-3-gaia-pt-br-4b-it
# 3           punchlines   few-shot             gemma-3-gaia-pt-br-4b-it
# 4         comic_styles   few-shot             gemma-3-gaia-pt-br-4b-it
# 5   texts_explanations   few-shot             gemma-3-gaia-pt-br-4b-it
# 6           punchlines  zero-shot            mixtral-8x7b-instruct-v01
# 7         comic_styles  zero-shot            mixtral-8x7b-instruct-v01
# 8   texts_explanations  zero-shot            mixtral-8x7b-instruct-v01
# 9           punchlines   few-shot            mixtral-8x7b-instruct-v01
# 10        comic_styles   few-shot            mixtral-8x7b-instruct-v01
# 11  texts_explanations   few-shot            mixtral-8x7b-instruct-v01
# ...

# %%
model_short_names = {
    'gemma-3-gaia-pt-br-4b-it': 'Gemma 3 Gaia (4B)',
    'mixtral-8x7b-instruct-v01': 'Mixtral v01 (8×7B)',
    'sabia-3.1': 'Sabia 3.1',
    'granite-3-3-8b-instruct': 'Granite 3.3 (8B)',
    'gemini-2.5-flash': 'Gemini 2.5 Flash',
    'gpt-4': 'GPT-4',
    'llama-3-405b-instruct': 'LLaMA 3 (405B)',
    'deepseek-r1-0528-qwen3-8b': 'DeepSeek R1 (8B)',
    'gervasio-7b-portuguese-ptbr-decoder': 'Gervasio (7B)'
}

df_long['model'] = df_long['model'].apply(lambda model_name: model_short_names[model_name])
df_long
# Out:
#                   task    setting               model  \
# 0           punchlines  zero-shot   Gemma 3 Gaia (4B)
# 1         comic_styles  zero-shot   Gemma 3 Gaia (4B)
# 2   texts_explanations  zero-shot   Gemma 3 Gaia (4B)
# 3           punchlines   few-shot   Gemma 3 Gaia (4B)
# 4         comic_styles   few-shot   Gemma 3 Gaia (4B)
# 5   texts_explanations   few-shot   Gemma 3 Gaia (4B)
# 6           punchlines  zero-shot  Mixtral v01 (8×7B)
# 7         comic_styles  zero-shot  Mixtral v01 (8×7B)
# 8   texts_explanations  zero-shot  Mixtral v01 (8×7B)
# 9           punchlines   few-shot  Mixtral v01 (8×7B)
# 10        comic_styles   few-shot  Mixtral v01 (8×7B)
# 11  texts_explanations   few-shot  Mixtral v01 (8×7B)
# 12          punchlines  zero-shot           Sabia 3.1
# 13        comic_styles  zero-shot           Sabia 3.1
# 14  texts_explanations  zero-shot           Sabia 3.1
# 15          punchlines   few-shot           Sabia 3.1
# ...

# %%
# 1. Filtrar só punchlines
df_punch = df_long.query("task == 'punchlines'").copy()
df_punch
# Out:
#           task    setting               model  \
# 0   punchlines  zero-shot   Gemma 3 Gaia (4B)
# 3   punchlines   few-shot   Gemma 3 Gaia (4B)
# 6   punchlines  zero-shot  Mixtral v01 (8×7B)
# 9   punchlines   few-shot  Mixtral v01 (8×7B)
# 12  punchlines  zero-shot           Sabia 3.1
# 15  punchlines   few-shot           Sabia 3.1
# 18  punchlines  zero-shot    Granite 3.3 (8B)
# 21  punchlines   few-shot    Granite 3.3 (8B)
# 24  punchlines  zero-shot    Gemini 2.5 Flash
# 27  punchlines   few-shot    Gemini 2.5 Flash
# 30  punchlines  zero-shot               GPT-4
# 33  punchlines   few-shot               GPT-4
# 36  punchlines  zero-shot       Gervasio (7B)
# 39  punchlines   few-shot       Gervasio (7B)
# 42  punchlines  zero-shot      LLaMA 3 (405B)
# 45  punchlines   few-shot      LLaMA 3 (405B)
# 48  punchlines  zero-shot    DeepSeek R1 (8B)
# 51  punchlines   few-shot    DeepSeek R1 (8B)
#
#                                                 score
# ...

# %%
valid_models = [
    model for model in df_punch['model'].unique()
    if all(
        isinstance(v, dict) and v.get('dice_similarity') is not None
        for v in df_punch.loc[df_punch['model'] == model, 'score']
    )
]

df_punch_plot = df_punch[df_punch['model'].isin(valid_models)]

# %%
import altair as alt
import os

df_plot = df_punch_plot.copy()
df_plot['dice_similarity'] = df_plot['score'].apply(lambda x: x['dice_similarity'] if isinstance(x, dict) else None)
dice_order = df_plot[df_plot['setting'] == 'zero-shot'].sort_values('dice_similarity', ascending=False)['model'].tolist()
df_plot['setting'] = pd.Categorical(df_plot['setting'], categories=['zero-shot', 'few-shot'], ordered=True)

chart_dice = alt.Chart(df_plot).mark_bar(size=20).encode(
    y=alt.Y('model:N', sort=dice_order, title=' ', axis=alt.Axis(grid=False)),
    x=alt.X('dice_similarity:Q', title='Média da Similaridade de Dice', axis=alt.Axis(grid=False, titleY=30)),
    color=alt.Color('setting:N', title='Configuração'),
    yOffset=alt.YOffset('setting:N')
).properties(
    width=500,
    height=400,
    title='Comparação Zero-shot vs Few-shot — Identificação de Punchlines'
)

visus_path = visus_folder_name
os.makedirs(visus_path, exist_ok=True)
chart_dice.save(os.path.join(visus_path, "similaridade_dice_vertical_barras.png"), scale_factor=3.0)
chart_dice.show()
# Out:
# alt.Chart(...)

# %%
df_texts = df_long.query("task == 'texts_explanations'").copy()
df_texts_plot = df_texts[df_texts['model'].isin(valid_models)]
df_texts_plot
# Out:
#                   task    setting              model     score
# 2   texts_explanations  zero-shot  Gemma 3 Gaia (4B)  3.391579
# 5   texts_explanations   few-shot  Gemma 3 Gaia (4B)  3.210526
# 14  texts_explanations  zero-shot          Sabia 3.1  4.195789
# 17  texts_explanations   few-shot          Sabia 3.1  4.090526
# 20  texts_explanations  zero-shot   Granite 3.3 (8B)  3.642105
# 23  texts_explanations   few-shot   Granite 3.3 (8B)  3.543158
# 26  texts_explanations  zero-shot   Gemini 2.5 Flash  4.635789
# 29  texts_explanations   few-shot   Gemini 2.5 Flash  4.307368
# 32  texts_explanations  zero-shot              GPT-4  4.282105
# 35  texts_explanations   few-shot              GPT-4  4.164211
# 44  texts_explanations  zero-shot     LLaMA 3 (405B)  3.972632
# 47  texts_explanations   few-shot     LLaMA 3 (405B)  3.696842
# 50  texts_explanations  zero-shot   DeepSeek R1 (8B)  2.776842
# 53  texts_explanations   few-shot   DeepSeek R1 (8B)  2.117895

# %%
df_plot = df_texts_plot.copy()
df_plot['metric'] = df_plot['score']
zero_shot_order = df_plot[df_plot['setting'] == 'zero-shot'].sort_values('metric', ascending=False)['model'].tolist()
df_plot['setting'] = pd.Categorical(df_plot['setting'], categories=['zero-shot', 'few-shot'], ordered=True)

chart_texts = alt.Chart(df_plot).mark_bar(size=20).encode(
    y=alt.Y('model:N', sort=zero_shot_order, title=' ', axis=alt.Axis(grid=False)),
    x=alt.X(
        'metric:Q',
        title='Média do Nível de Concordância - Modelo Juiz',
        axis=alt.Axis(grid=False, titleY=30),
        scale=alt.Scale(domain=[1, 5], clamp = True) 
    ),
    color=alt.Color('setting:N', title='Configuração'),
    yOffset=alt.YOffset('setting:N')
).properties(
    width=500,
    height=400,
    title='Comparação Zero-shot vs Few-shot — Explicações dos Textos'
)

visus_path = visus_folder_name
os.makedirs(visus_path, exist_ok=True)
chart_texts.save(os.path.join(visus_path, "texts_explanations_vertical_barras.png"), scale_factor=3.0)
chart_texts.show()
# Out:
# alt.Chart(...)

# %%
df_comic = df_long.query("task == 'comic_styles'").copy()
df_comic
# Out:
#             task    setting               model  \
# 1   comic_styles  zero-shot   Gemma 3 Gaia (4B)
# 4   comic_styles   few-shot   Gemma 3 Gaia (4B)
# 7   comic_styles  zero-shot  Mixtral v01 (8×7B)
# 10  comic_styles   few-shot  Mixtral v01 (8×7B)
# 13  comic_styles  zero-shot           Sabia 3.1
# 16  comic_styles   few-shot           Sabia 3.1
# 19  comic_styles  zero-shot    Granite 3.3 (8B)
# 22  comic_styles   few-shot    Granite 3.3 (8B)
# 25  comic_styles  zero-shot    Gemini 2.5 Flash
# 28  comic_styles   few-shot    Gemini 2.5 Flash
# 31  comic_styles  zero-shot               GPT-4
# 34  comic_styles   few-shot               GPT-4
# 37  comic_styles  zero-shot       Gervasio (7B)
# 40  comic_styles   few-shot       Gervasio (7B)
# 43  comic_styles  zero-shot      LLaMA 3 (405B)
# 46  comic_styles   few-shot      LLaMA 3 (405B)
# 49  comic_styles  zero-shot    DeepSeek R1 (8B)
# 52  comic_styles   few-shot    DeepSeek R1 (8B)
#
# ...

# %%
valid_models = [
    model for model in df_comic['model'].unique()
    if all(
        isinstance(v, dict) and 'f1_score' in v and all(pd.notna(score) for score in v['f1_score'].values())
        for v in df_comic.loc[df_comic['model'] == model, 'score']
    )
]

df_comic_plot = df_comic[df_comic['model'].isin(valid_models)].copy()

# Expandir os dicionários f1_score em linhas longas
rows = []
for _, row in df_comic_plot.iterrows():
    f1_scores = row['score']['f1_score']
    for style, value in f1_scores.items():
        if pd.notna(value):
            rows.append({
                'model': row['model'],
                'setting': row['setting'],
                'style': style,
                'score': value
            })

df_comic_long = pd.DataFrame(rows)

# Calcular média por modelo e cenário
df_comic_mean = (
    df_comic_long
    .groupby(['model', 'setting'], as_index=False)['score']
    .mean()
)

# Ordenar modelos pela média zero-shot
model_order = (
    df_comic_mean[df_comic_mean['setting'] == 'zero-shot']
    .sort_values('score', ascending=False)['model']
    .tolist()
)

# Transformar setting em categoria ordenada
df_comic_mean['setting'] = pd.Categorical(df_comic_mean['setting'], categories=['zero-shot', 'few-shot'], ordered=True)

# Gráfico horizontal: zero-shot acima do few-shot
chart_comic = alt.Chart(df_comic_mean).mark_bar(size=20).encode(
    y=alt.Y('model:N', sort=model_order, title=' ', axis=alt.Axis(grid=False)),
    x=alt.X('score:Q', title='Média F1 Score (Estilos Cômicos)', 
            axis=alt.Axis(grid=False, titleY=30),
            scale=alt.Scale(domain=[0, 1], clamp=True)),
    color=alt.Color('setting:N', title='Configuração'),
    yOffset=alt.YOffset('setting:N')
).properties(
    width=500,
    height=400,
    title='Comparação Zero-shot vs Few-shot — Estilos Cômicos'
)

# Salvar e mostrar
visus_path = visus_folder_name
os.makedirs(visus_path, exist_ok=True)
chart_comic.save(os.path.join(visus_path, "comic_styles_media_f1score.png"), scale_factor=3.0)
chart_comic.show()
# Out:
# alt.Chart(...)

# %%
valid_models = [
    model for model in df_comic['model'].unique()
    if all(
        isinstance(v, dict) and 'f1_score' in v and all(pd.notna(score) for score in v['f1_score'].values())
        for v in df_comic.loc[df_comic['model'] == model, 'score']
    ) and model != 'Gemini 2.5 Flash'
]

df_comic_plot = df_comic[df_comic['model'].isin(valid_models)].copy()

# Expandir os dicionários f1_score em linhas longas
rows = []
for _, row in df_comic_plot.iterrows():
    f1_scores = row['score']['f1_score']
    for style, value in f1_scores.items():
        if pd.notna(value):
            rows.append({
                'model': row['model'],
                'setting': row['setting'],
                'style': style,
                'score': value
            })

df_comic_long = pd.DataFrame(rows)

# Ordenar modelos pelo zero-shot (média de todos os estilos)
model_order = (
    df_comic_long[df_comic_long['setting'] == 'zero-shot']
    .groupby('model')['score'].mean()
    .sort_values(ascending=False)
    .index.tolist()
)

# Transformar setting em categoria ordenada
df_comic_long['setting'] = pd.Categorical(df_comic_long['setting'], categories=['zero-shot', 'few-shot'], ordered=True)

# Gráfico horizontal: barras por estilo, zero-shot acima do few-shot
chart_comic = alt.Chart(df_comic_long).mark_bar(size=20).encode(
    y=alt.Y('model:N', sort=model_order, title=' ', axis=alt.Axis(grid=False)),
    x=alt.X('score:Q', title='F1 Score', axis=alt.Axis(grid=False, titleY=30), scale=alt.Scale(domain=[0,1], clamp=True)),
    color=alt.Color('setting:N', title='Configuração'),
    yOffset=alt.YOffset('setting:N'),
    column=alt.Column('style:N', title=' ')  # cada estilo em uma coluna
).properties(
    width=150,
    height=400,
    title='Comparação Zero-shot vs Few-shot — Estilos Cômicos (F1 Score)'
)

# Salvar e mostrar
visus_path = visus_folder_name
os.makedirs(visus_path, exist_ok=True)
chart_comic.save(os.path.join(visus_path, "comic_styles_vertical_barras.png"), scale_factor=3.0)
chart_comic.show()
# Out:
# alt.Chart(...)
